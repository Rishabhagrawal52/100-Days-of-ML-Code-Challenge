# %% [markdown]
# #making up a model of polynomial regression on random dataset

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(2)
pagespeeds=np.random.normal(3.0,1.0,1000)
purchaseamount=np.random.normal(50.0,10.0,1000)/pagespeeds
plt.scatter(pagespeeds,purchaseamount)

# %% [markdown]
# # using 1 degree polynomial

# %%
X=np.array(pagespeeds)
Y=np.array(purchaseamount)
P1=np.poly1d(np.polyfit(X,Y,1))

# %%
XP=np.linspace(0,7,100)
plt.scatter(X,Y)
plt.plot(XP,P1(XP))
plt.show()

# %%
#R-squared error
from sklearn.metrics import r2_score
r2error=r2_score(Y,P1(X))
print(r2error)
# Out:
# 0.5024941304548025

# %% [markdown]
# # using 2 degree polynomial

# %%
X=np.array(pagespeeds)
Y=np.array(purchaseamount)
P2=np.poly1d(np.polyfit(X,Y,2))

# %%
XP=np.linspace(0,7,100)
plt.scatter(X,Y)
plt.plot(XP,P2(XP))
plt.show()

# %%
#R-squared error
from sklearn.metrics import r2_score
r2error=r2_score(Y,P2(X))
print(r2error)
# Out:
# 0.6927446350535892

# %% [markdown]
# # using 3 degree polynomial

# %%
X=np.array(pagespeeds)
Y=np.array(purchaseamount)
P3=np.poly1d(np.polyfit(X,Y,3))

# %%
XP=np.linspace(0,7,100)
plt.scatter(X,Y)
plt.plot(XP,P3(XP))
plt.show()

# %%
#R-squared error
from sklearn.metrics import r2_score
r2error=r2_score(Y,P3(X))
print(r2error)
# Out:
# 0.7842354030823269

# %% [markdown]
# # using 4 degree polynomial

# %%
X=np.array(pagespeeds)
Y=np.array(purchaseamount)
P4=np.poly1d(np.polyfit(X,Y,4))

# %%
XP=np.linspace(0,7,100)
plt.scatter(X,Y)
plt.plot(XP,P4(XP))
plt.show()

# %%
#R-squared error
from sklearn.metrics import r2_score
r2error=r2_score(Y,P4(X))
print(r2error)
# Out:
# 0.8293766396303073

# %% [markdown]
# # using 6 degree polynomial

# %%
X=np.array(pagespeeds)
Y=np.array(purchaseamount)
P6=np.poly1d(np.polyfit(X,Y,6))

# %%
XP=np.linspace(0,7,100)
plt.scatter(X,Y)
plt.plot(XP,P6(XP))
plt.show()

# %%
#R-squared error
from sklearn.metrics import r2_score
r2error=r2_score(Y,P6(X))
print(r2error)
# Out:
# 0.8700733999871757

# %% [markdown]
# # using 8 degree polynomial

# %%
X=np.array(pagespeeds)
Y=np.array(purchaseamount)
P8=np.poly1d(np.polyfit(X,Y,8))

# %%
XP=np.linspace(0,7,100)
plt.scatter(X,Y)
plt.plot(XP,P8(XP))
plt.show()

# %%
#R-squared error
from sklearn.metrics import r2_score
r2error=r2_score(Y,P8(X))
print(r2error)
# Out:
# 0.8814395663681512
